# %%
import tensorflow as tf
import pandas as pd
import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Conv2D, MaxPool2D, LeakyReLU, BatchNormalization, Dropout, Dense, InputLayer, Flatten
from keras.losses import SparseCategoricalCrossentropy
from keras.optimizers import Adam


fashion_mnist = tf.keras.datasets.fashion_mnist

(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()


model = keras.Sequential()


#Dense Layers
model.add(InputLayer(input_shape=(28,28,1)))
model.add(Conv2D(filters=32,kernel_size=3, activation="relu", padding="same"))
model.add(MaxPool2D())
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(10))



model.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_8 (Conv2D)           (None, 28, 28, 32)        320
#
#  max_pooling2d_6 (MaxPooling  (None, 14, 14, 32)       0
#  2D)
#
#  flatten_10 (Flatten)        (None, 6272)              0
#
#  dense_24 (Dense)            (None, 128)               802944
#
#  dense_25 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 804,554
# Trainable params: 804,554
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer=Adam(),loss = SparseCategoricalCrossentropy(from_logits=True),metrics=['accuracy'])

# %%
train_images = train_images / 255.0

test_images = test_images / 255.0

# %%
model.fit(train_images, train_labels, epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 29s 15ms/step - loss: 0.3773 - accuracy: 0.8662
# Epoch 2/10
# 1875/1875 [==============================] - 28s 15ms/step - loss: 0.2558 - accuracy: 0.9061
# Epoch 3/10
# 1875/1875 [==============================] - 28s 15ms/step - loss: 0.2118 - accuracy: 0.9221
# Epoch 4/10
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.1817 - accuracy: 0.9323
# Epoch 5/10
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.1542 - accuracy: 0.9425
# Epoch 6/10
# 1875/1875 [==============================] - 28s 15ms/step - loss: 0.1301 - accuracy: 0.9517
# Epoch 7/10
# 1875/1875 [==============================] - 27s 15ms/step - loss: 0.1087 - accuracy: 0.9603
# Epoch 8/10
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.0926 - accuracy: 0.9661
# Epoch 9/10
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.0768 - accuracy: 0.9721
# Epoch 10/10
# 1875/1875 [==============================] - 28s 15ms/step - loss: 0.0672 - accuracy: 0.9752

# %%
model.save('fashion.keras')

# %%
test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)

print('\nTest accuracy:', test_acc)
# Out:
# 313/313 - 2s - loss: 0.3418 - accuracy: 0.9150 - 2s/epoch - 5ms/step
#
# Test accuracy: 0.9150000214576721
